# %% [markdown]
# # Pattern Recognition
#
# # Lucas Nogueira Ribeiro

# %% [markdown]
# ## First exercise: covariance matrices

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import numpy as np
import pylab as pl
import scipy as sc

mu = np.array([[3.0],[1.0],[2.0]])
mu.shape = (3,1) # Force mu to be a column vector

K = np.array([[0.5, 0.2, 0.1],
              [0.6, 0.18, 0.4],
              [0.1, 0.6, 0.2]])

x = np.array([[0],[0.5], [1]])
x.shape = (3,1)

# %% [markdown]
# ### Util functions

# %%
def getPartitions(M):
    if not isinstance(M, np.ndarray):
        raise TypeError('O argumento M deve ser do tipo numpy.ndarray')
    
    if M.shape == (3,3):
        Maa = M[0:2, 0:2]
        Mbb = M[2,2]
        Mab = M[0:2,2]
        Mba = M[2,0:2]

        # Force Mab and Mba to be column and row vectors
        Mab.shape = (2,1)
        Mba.shape = (1,2)

        return Maa, Mbb, Mab, Mba
    elif M.shape == (3,1):
        Ma = M[0:2]
        Mb = M[2]

        # Force Ma to be a column vector
        Ma.shape = (2,1)

        return Ma, Mb
    else:
        raise Exception('Argumento M deve ser uma matriz de dimensões 3x3 ou 3x1.')

def getPrecision(C):
    return np.linalg.inv(C)

def getCondCov(C):
    Caa, Cbb, Cab, Cba = getPartitions(C)
    #iCbb = np.linalg.inv(Cbb)
    iCbb = 1.0/Cbb
    return Caa - np.dot(Cab, np.dot(iCbb, Cba))

def getCondMean(C, mu, x):
    Caa, Cbb, Cab, Cba = getPartitions(C)
    #iCbb = np.linalg.inv(Cbb)
    iCbb = 1.0/Cbb
    mu_a, mu_b = getPartitions(mu)  
    xa, xb = getPartitions(x)
    aux = np.dot(np.dot(Cab, iCbb),(xb - mu_b))
    aux.shape = (2,1)
    return mu_a + aux

def getCondProb(x, C):
    xa, xb = getPartitions(x)
    ma, mb = getPartitions(mu)
    P = getPrecision(C)
    Paa, Pbb, Pab, Pba = getPartitions(P)
    
    e_aa = -0.5*np.dot((xa - ma).T, np.dot(Paa, (xa - ma)))
    e_ab = -0.5*np.dot((xa - ma).T, np.dot(Pab, (xb - mb)))
    e_ba = -0.5*np.dot((xb - mb).T, np.dot(Pba, (xa - ma)))
    e_bb = -0.5*np.dot((xb - mb).T, np.dot(Pbb, (xb - mb)))
    
    e = e_aa - e_ab - e_ba - e_bb
    f = (1.0/((2*np.pi)**(3.0/2.0)))*1.0/(np.sqrt(np.linalg.det(C)))
    
    return f*np.exp(e)
        
def printInfo(C):
    # Calculate the partitions of the covariance matrix
    Caa, Cbb, Cab, Cba = getPartitions(C)
    print 'Caa:'
    print Caa
    print 'Cbb:'
    print Cbb
    print 'Cab:'
    print Cab
    print 'Cba:'
    print Cba

    # Calculate the partitions of the precision matrix
    P = getPrecision(C)
    Paa, Pbb, Pab, Pba = getPartitions(P)

    # Calculate the conditional covariance matrix
    condC = getCondCov(C)
    print 'condC:'
    print condC

    # Calculate the partitions of the mean vector
    mu_a, mu_b = getPartitions(mu)
    print 'mu:'
    print mu
    print 'mu_a:'
    print mu_a
    print 'mu_b:'
    print mu_b

    # Calculate the conditional mean vector
    condMean = getCondMean(C, mu, x)
    print 'condMean:'
    print condMean

    # Calculate the probability 
    prob = getCondProb(x, C)
    print 'prob: ', prob

# %% [markdown]
# ### First covariance matrix

# %%
# Build covariance matrix
k = 4.0
C1 = k * np.eye(3)
print 'C1:'
print C1

printInfo(C1)
# Out:
# C1:
# [[ 4.  0.  0.]
#  [ 0.  4.  0.]
#  [ 0.  0.  4.]]
# Caa:
# [[ 4.  0.]
#  [ 0.  4.]]
# Cbb:
# 4.0
# Cab:
# [[ 0.]
#  [ 0.]]
# Cba:
# [[ 0.  0.]]
# condC:
# [[ 4.  0.]
#  [ 0.  4.]]
# mu:
# [[ 3.]
#  [ 1.]
#  [ 2.]]
# mu_a:
# [[ 3.]
#  [ 1.]]
# mu_b:
# [ 2.]
# condMean:
# [[ 3.]
#  [ 1.]]
# prob:  [[ 0.00282992]]

# %% [markdown]
# ### Second covariance matrix

# %%
# Build covariance matrix
C2 = np.dot(K, K.T)
print 'C2:'
print C2

printInfo(C2)
# Out:
# C2:
# [[ 0.3     0.376   0.19  ]
#  [ 0.376   0.5524  0.248 ]
#  [ 0.19    0.248   0.41  ]]
# Caa:
# [[ 0.3     0.376 ]
#  [ 0.376   0.5524]]
# Cbb:
# 0.41
# Cab:
# [[ 0.19 ]
#  [ 0.248]]
# Cba:
# [[ 0.19   0.248]]
# condC:
# [[ 0.21195122  0.26107317]
#  [ 0.26107317  0.40239024]]
# mu:
# [[ 3.]
#  [ 1.]
#  [ 2.]]
# mu_a:
# [[ 3.]
#  [ 1.]]
# mu_b:
# [ 2.]
# condMean:
# [[ 2.53658537]
#  [ 0.39512195]]
# prob:  [[  5.16316190e-39]]

# %% [markdown]
# ### Thrid covariance matrix

# %%
# Build covariance matrix
C3 = np.zeros((3,3))

d = np.diag(C2)

for n in range(3):
    C3[n,n] = d[n]
    
print C3

printInfo(C3)
# Out:
# [[ 0.3     0.      0.    ]
#  [ 0.      0.5524  0.    ]
#  [ 0.      0.      0.41  ]]
# Caa:
# [[ 0.3     0.    ]
#  [ 0.      0.5524]]
# Cbb:
# 0.41
# Cab:
# [[ 0.]
#  [ 0.]]
# Cba:
# [[ 0.  0.]]
# condC:
# [[ 0.3     0.    ]
#  [ 0.      0.5524]]
# mu:
# [[ 3.]
#  [ 1.]
#  [ 2.]]
# mu_a:
# [[ 3.]
#  [ 1.]]
# mu_b:
# [ 2.]
# condMean:
# [[ 3.]
#  [ 1.]]
# prob:  [[  2.01180803e-07]]

# %% [markdown]
# ## Second exercise: covariance matrices
#
# $ \mathcal{N}(\mathbf{x}|\mathbf{\mu}, \mathbf{\Sigma}) = \frac{1}{(2\pi)^{D/2}}  \frac{1}{|\Sigma|^{1/2}}\exp^{-\frac{1}{2}(\mathbf{x}-\mathbf{\mu})^T \Sigma^{-1}(\mathbf{x}-\mathbf{\mu})}$

# %% [markdown]
# ### First covariance matrix

# %%
Caa, Cbb, Cab, Cba = getPartitions(C1)
ma, mb = getPartitions(mu)
xa, xb = getPartitions(x)

iCbb = 1.0/Cbb
f = (1.0/((2*np.pi)**(3.0/2.0)))*1.0/(np.sqrt(np.linalg.det(C1)))
pb = f * np.exp(-0.5*np.dot((xb-mb).T, np.dot(iCbb, (xb-mb))))
print pb
print mb
print Cbb
# Out:
# 0.00700411713073
# [ 2.]
# 4.0

# %% [markdown]
# ### Second covariance matrix

# %%
Caa, Cbb, Cab, Cba = getPartitions(C2)
ma, mb = getPartitions(mu)
xa, xb = getPartitions(x)

iCbb = 1.0/Cbb
f = (1.0/((2*np.pi)**(3.0/2.0)))*1.0/(np.sqrt(np.linalg.det(C2)))
pb = f * np.exp(-0.5*np.dot((xb-mb).T, np.dot(iCbb, (xb-mb))))
print pb
print mb
print Cbb
# Out:
# 0.223799319618
# [ 2.]
# 0.41

# %% [markdown]
# ### Third covariance matrix

# %%
Caa, Cbb, Cab, Cba = getPartitions(C3)
ma, mb = getPartitions(mu)
xa, xb = getPartitions(x)

iCbb = 1.0/Cbb
f = (1.0/((2*np.pi)**(3.0/2.0)))*1.0/(np.sqrt(np.linalg.det(C3)))
pb = f * np.exp(-0.5*np.dot((xb-mb).T, np.dot(iCbb, (xb-mb))))
print pb
print mb
print Cbb
# Out:
# 0.0719487726472
# [ 2.]
# 0.41

# %% [markdown]
# ## Third exercise:  Student's t distribution

# %%
from scipy.special import gamma

def student(x, mu, lamb, upsilon):
    g = gamma(upsilon/2.0 + 0.5)/gamma(upsilon/2.0)
    l = np.sqrt(lamb/(np.pi*upsilon))
    f = (1 + (lamb*(x-mu)**2.0)/upsilon)**(-upsilon/2.0-0.5)
    return g*l*f

def gauss(x, mu, sigma):
    return (1.0/(np.sqrt(2*np.pi*sigma**2.0)))*np.exp((-1.0/(2*sigma**2.0))*(x-mu)**2.0)

# %%
# plot parameters
mu = 0.0   
lamb = 1.0  # replace with 2.0 (weird curves ...)
sigma = 1.0
t = np.linspace(-10.0, 10.0, 1000)
upsilon_style_list = [(0.01,'r'), (0.1,'g'), (1, 'b'), (10,'k'), (100, 'm')]

pl.figure()

# plot student distributions
for upsilon, style in upsilon_style_list:
    y = [ student(x, mu, lamb, upsilon) for x in t]
    pl.plot(t, y, style)
    
# plot gaussian distribution    
g = [ gauss(x, mu, sigma) for x in t]
pl.plot(t, g, '--k')

# configure figure
pl.xlabel('$x$', fontsize=12)
pl.ylabel('St[$x,\mu,\lambda,\upsilon$]', fontsize=12)
pl.title('$\mu$ = {}, $\lambda$ = {}, $\sigma$ = {}'.format(mu, lamb, sigma), fontsize=12)
pl.legend(['$\upsilon$ = 0.01',
          '$\upsilon$ = 0.1',
          '$\upsilon$ = 1',
          '$\upsilon$ = 10',
          '$\upsilon$ = 100',
          'Gaussian ($\sigma$ = 1)'], fontsize=10)

# %% [markdown]
# ## Fourth exercise: mixture of gaussians

# %%
x = np.loadtxt('03_Assignment_data/03_Assignment_data-B.txt')
print x.shape
# Out:
# (190,)

# %%
def gmm(k, weights, means):
    if weights.sum() != 1.0:
        raise Exception('a soma deve ser 1.0')
        
    val = 0.0        
    for n in range(weights.size):
        val += weights[n] * gauss(k, means[n], 1.0)
    
    return val

# %%
interval = np.linspace(-20, 60, 1000)
weights = np.array([0.25, 0.175, 0.125, 0.125, 0.175, 0.15])
means = np.array([-10, -6, 12, 15, 19, 50])
mixture = [ gmm(k, weights, means) for k in interval]

pl.figure()
n, bins, patches = pl.hist(x, bins=50, normed=True)
pl.plot(interval, mixture, 'r')

# %% [markdown]
# ## Fifth exercise: Kernel density estimators

# %%
x = np.loadtxt('03_Assignment_data/03_Assignment_data-B.txt')
print x.shape
# Out:
# (190,)

# %%
def parzenkernel(k, xn, h):
    if np.abs((k-xn)/h) <= 0.5:
        return 1.0/h
    else:
        return 0.0
    
def gausskernel(k, xn, h):
    return (1.0/(h*np.sqrt(2*np.pi)))*np.exp(-(np.abs(k-xn)**2.0)/(2*h**2))
    
    
def kde(interval, x, h, method):
    T = interval.size
    N = x.size
    
    pdf = np.zeros((T,))
    for t in range(T):
        k = interval[t] # probe value
        
        pdf[t] = 0.0
        if method == 'parzen':
            for n in range(N):
                xn = x[n]
                pdf[t] += parzenkernel(k, xn, h)/N
        elif method == 'gauss':
            for n in range(N):
                xn = x[n]
                pdf[t] += gausskernel(k, xn, h)/N
        else:
            raise ValueError('Invalid argument method.')

    return pdf

# %%
h_list = [0.5, 1, 2]
interval = np.linspace(-20, 60, 1000)

pl.figure()
for h in h_list:
    pdf = kde(interval, x, h, 'gauss')
    pl.plot(interval, pdf)

pl.title('Gaussian Window')
pl.legend(['$h=0.5$', '$h=1$', '$h=2$'])
pl.ylim([0, 0.10])
# Out:
# (0, 0.1)

# %%
pl.figure()
for h in h_list:
    pdf = kde(interval, x, h, 'parzen')
    pl.plot(interval, pdf)

pl.title('Parzen Window')
pl.legend(['$h=0.5$', '$h=1$', '$h=2$'])
pl.ylim([0, 0.20])
# Out:
# (0, 0.2)

# %% [markdown]
# ## Sixth exercise

# %%
x_learning_input = np.loadtxt('03_Assignment_data/03_Assignment_data-C-learning-input.txt')
print x_learning_input.shape

x_learning_output = np.loadtxt('03_Assignment_data/03_Assignment_data-C-learning-output.txt')
print x_learning_output.shape

from mpl_toolkits.mplot3d import Axes3D # needed to generate 3d plots

fig = pl.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_learning_input[:,0],
          x_learning_input[:,1],
          x_learning_output)
ax.set_xlabel('$x_0$')
ax.set_ylabel('$x_1$')
ax.set_zlabel('$t$')
# Out:
# (2000, 2)
# (2000,)

# %%
x_test_input = np.loadtxt('03_Assignment_data/03_Assignment_data-C-test-input.txt')
print x_test_input.shape

x_test_output = np.loadtxt('03_Assignment_data/03_Assignment_data-C-test-output.txt')
print x_test_output.shape

fig = pl.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_test_input[:,0],
          x_test_input[:,1],
          x_test_output)
ax.set_xlabel('$x_0$')
ax.set_ylabel('$x_1$')
ax.set_zlabel('$t$')
# Out:
# (1000, 2)
# (1000,)

# %%
x_validation_input = np.loadtxt('03_Assignment_data/03_Assignment_data-C-validation-input.txt')
print x_validation_input.shape

x_validation_output = np.loadtxt('03_Assignment_data/03_Assignment_data-C-validation-output.txt')
print x_validation_output.shape

fig = pl.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_validation_input[:,0],
          x_validation_input[:,1],
          x_validation_output)
ax.set_xlabel('$x_0$')
ax.set_ylabel('$x_1$')
ax.set_zlabel('$t$')
# Out:
# (1000, 2)
# (1000,)

# %%
def mse(y, t):
    error = y - t
    squared_error = np.abs(error)**2.0
    N = y.shape[0]
    return (1.0/N)*squared_error.sum()

def gaussbf(xn, mu):
    return np.exp(-0.5*np.linalg.norm(xn - mu)**2)

def gausslearn(x, t, M):     
    N = x.shape[0]         # number of samples
    ones = np.ones((N,1))
    Sig = np.zeros((N,M))  # initialize design matrix
    for m in range(M): 
        mu = x[m,:]  
        for n in range(N):
            xn = x[n,:]
            Sig[n,m] = gaussbf(xn, mu)
            
    Sig = np.concatenate((ones, Sig), axis=1)
    # print Sig
    
    w = np.dot(np.linalg.pinv(Sig), t)
    y = np.dot(Sig, w)
    return y, w

def lslearn(x, t):
    N = x.shape[0]
    ones = np.ones((N,1)) # bias elements
    Sig = np.concatenate((ones, x), axis=1)
    w = np.dot(np.linalg.pinv(Sig), t)
    y = np.dot(Sig, w)
    return y, w

# %% [markdown]
# ### Classic least-squares (identity)

# %%
x = x_learning_input
t = x_learning_output

(y, w) = lslearn(x, t)
print 'MSE: ', mse(y, t)
for n in range(20):
    eq = np.abs(y[n]-t[n])**2
    print 'training: {:.3f} - predicted: {:.3f} - quadratic error: {:.3f}'.format(t[n], y[n], eq)
# Out:
# MSE:  1.03728146352
# training: 1.773 - predicted: 2.704 - quadratic error: 0.866
# training: 4.942 - predicted: 4.081 - quadratic error: 0.741
# training: 4.754 - predicted: 3.072 - quadratic error: 2.827
# training: 1.960 - predicted: 3.630 - quadratic error: 2.787
# training: 5.014 - predicted: 3.627 - quadratic error: 1.924
# training: 3.709 - predicted: 2.304 - quadratic error: 1.974
# training: 4.254 - predicted: 3.188 - quadratic error: 1.136
# training: 1.703 - predicted: 3.031 - quadratic error: 1.763
# training: 1.771 - predicted: 2.742 - quadratic error: 0.943
# training: 3.774 - predicted: 3.134 - quadratic error: 0.410
# training: 4.266 - predicted: 3.119 - quadratic error: 1.314
# training: 2.770 - predicted: 3.418 - quadratic error: 0.421
# training: 3.325 - predicted: 2.575 - quadratic error: 0.563
# training: 3.759 - predicted: 3.152 - quadratic error: 0.368
# training: 2.023 - predicted: 2.312 - quadratic error: 0.084
# training: 2.243 - predicted: 2.498 - quadratic error: 0.065
# training: 2.285 - predicted: 3.516 - quadratic error: 1.517
# training: 2.391 - predicted: 2.022 - quadratic error: 0.136
# training: 3.601 - predicted: 3.106 - quadratic error: 0.245
# training: 4.929 - predicted: 3.683 - quadratic error: 1.552

# %% [markdown]
# #### Validation

# %%
t_learning = x_learning_output
t_test = x_test_output

(y_learning, w_learning) = lslearn(x_learning_input, t_learning)
(y_test, w_test) = lslearn(x_test_input, t_test)

print 'MSE [learning]: ', mse(y_learning, t_learning)
print 'MSE [test]: ', mse(y_test, t_test)
# Out:
# MSE [learning]:  1.03728146352
# MSE [test]:  1.10867871973

# %% [markdown]
# ### Gaussian basis function

# %%
t = x_learning_output
(y, w) = gausslearn(x_learning_input, t, 128)
print 'MSE: ', mse(y, t)

for n in range(20):
    eq = np.abs(y[n]-t[n])**2
    print 'training: {:.3f} - predicted: {:.3f} - quadratic error: {:.3f}'.format(t[n], y[n], eq)
# Out:
# MSE:  0.0638628585438
# training: 1.773 - predicted: 2.038 - quadratic error: 0.070
# training: 4.942 - predicted: 4.308 - quadratic error: 0.402
# training: 4.754 - predicted: 4.950 - quadratic error: 0.038
# training: 1.960 - predicted: 2.024 - quadratic error: 0.004
# training: 5.014 - predicted: 4.669 - quadratic error: 0.119
# training: 3.709 - predicted: 3.815 - quadratic error: 0.011
# training: 4.254 - predicted: 4.458 - quadratic error: 0.042
# training: 1.703 - predicted: 1.317 - quadratic error: 0.149
# training: 1.771 - predicted: 1.980 - quadratic error: 0.044
# training: 3.774 - predicted: 3.583 - quadratic error: 0.037
# training: 4.266 - predicted: 4.221 - quadratic error: 0.002
# training: 2.770 - predicted: 3.249 - quadratic error: 0.230
# training: 3.325 - predicted: 3.305 - quadratic error: 0.000
# training: 3.759 - predicted: 3.835 - quadratic error: 0.006
# training: 2.023 - predicted: 2.180 - quadratic error: 0.025
# training: 2.243 - predicted: 1.783 - quadratic error: 0.212
# training: 2.285 - predicted: 2.610 - quadratic error: 0.106
# training: 2.391 - predicted: 2.208 - quadratic error: 0.033
# training: 3.601 - predicted: 3.456 - quadratic error: 0.021
# training: 4.929 - predicted: 4.650 - quadratic error: 0.078

# %% [markdown]
# #### Find the optimum basis function number

# %%
M_list = range(2, 70, 4)
MSE_list = []
norm_list = []
t = x_learning_output
for M in M_list:
    print 'M = {}...'.format(M)
    (y, w) = gausslearn(x_learning_input, t, M)
    MSE_list.append(mse(y,t))
    norm_list.append(np.linalg.norm(w))
# Out:
# M = 2...
# M = 6...
# M = 10...
# M = 14...
# M = 18...
# M = 22...
# M = 26...
# M = 30...
# M = 34...
# M = 38...
# M = 42...
# M = 46...
# M = 50...
# M = 54...
# M = 58...
# M = 62...
# M = 66...

# %%
pl.figure()
pl.title('Gaussian basis function')

pl.subplot(121)
pl.plot(M_list, MSE_list, '-o')
pl.xlabel('M [number of basis functions]')
pl.ylabel('MSE')
pl.grid()    


pl.subplot(122)
pl.plot(M_list, norm_list, '-o')
pl.xlabel('M [number of basis functions]')
pl.ylabel('norm of $\mathbf{w}$')
pl.grid()

pl.tight_layout()

# %% [markdown]
# #### Validation

# %%
M = 50

t_learning = x_learning_output
t_test = x_test_output

(y_learning, w_learning) = gausslearn(x_learning_input, t_learning, M)
(y_test, w_test) = gausslearn(x_test_input, t_test, M)

print w_test.shape

print 'MSE [learning]: ', mse(y_learning, t_learning)
print 'MSE [test]: ', mse(y_test, t_test)
# Out:
# (51,)
# MSE [learning]:  0.0641684270124
# MSE [test]:  0.0593469225178

# %% [markdown]
# ## Seventh exercise

# %%
def gausslearnreg(x, t, M, lamb):     
    N = x.shape[0]         # number of samples
    ones = np.ones((N,1))
    Sig = np.zeros((N,M))  # initialize design matrix
    for m in range(M): 
        mu = x[m,:]  
        for n in range(N):
            xn = x[n,:]
            Sig[n,m] = gaussbf(xn, mu)
            
    Sig = np.concatenate((ones, Sig), axis=1)
    # print Sig
        
    identity = np.eye(M+1)
    pinv = np.dot(np.linalg.inv(lamb*identity + np.dot(Sig.T, Sig)), Sig.T)
    
    w = np.dot(pinv, t)
    y = np.dot(Sig, w)
    return y, w

# %%
t = x_learning_output
(y, w) = gausslearnreg(x_learning_input, t, 20, 10)
print 'MSE: ', mse(y, t)

for n in range(20):
    eq = np.abs(y[n]-t[n])**2
    print 'training: {:.3f} - predicted: {:.3f} - quadratic error: {:.3f}'.format(t[n], y[n], eq)
# Out:
# MSE:  1.04913613644
# training: 1.773 - predicted: 2.696 - quadratic error: 0.852
# training: 4.942 - predicted: 3.780 - quadratic error: 1.349
# training: 4.754 - predicted: 3.179 - quadratic error: 2.481
# training: 1.960 - predicted: 3.621 - quadratic error: 2.757
# training: 5.014 - predicted: 3.643 - quadratic error: 1.878
# training: 3.709 - predicted: 2.268 - quadratic error: 2.077
# training: 4.254 - predicted: 3.128 - quadratic error: 1.267
# training: 1.703 - predicted: 3.165 - quadratic error: 2.136
# training: 1.771 - predicted: 2.770 - quadratic error: 0.998
# training: 3.774 - predicted: 3.038 - quadratic error: 0.542
# training: 4.266 - predicted: 2.945 - quadratic error: 1.743
# training: 2.770 - predicted: 3.415 - quadratic error: 0.416
# training: 3.325 - predicted: 2.558 - quadratic error: 0.589
# training: 3.759 - predicted: 3.041 - quadratic error: 0.516
# training: 2.023 - predicted: 2.326 - quadratic error: 0.092
# training: 2.243 - predicted: 2.528 - quadratic error: 0.081
# training: 2.285 - predicted: 3.611 - quadratic error: 1.759
# training: 2.391 - predicted: 1.975 - quadratic error: 0.173
# training: 3.601 - predicted: 3.276 - quadratic error: 0.106
# training: 4.929 - predicted: 3.697 - quadratic error: 1.519

# %%
A = np.random.randn(10, 3)
print A
print
print np.dot(np.linalg.inv(np.dot(A.T, A)), A.T)
print
print np.linalg.pinv(A)
# Out:
# [[-0.46342867 -1.86858391  0.91895823]
#  [-0.67564253 -0.05887469 -1.1563423 ]
#  [-1.16977017  0.16771673  2.19981989]
#  [-0.74727731  0.34955209  1.01288012]
#  [ 1.39672879 -1.23305463  0.01999759]
#  [-0.17763983  1.22309574  0.1205895 ]
#  [ 0.47047886  1.428731   -0.05418319]
#  [ 0.69255762 -0.23666232  0.22436435]
#  [-0.28984897 -0.74248633  0.08467813]
#  [ 0.87230123 -1.95812141 -0.3872357 ]]
#
# [[-0.10668773 -0.2601683  -0.06234038 -0.06414418  0.26529176  0.02480052
#    0.1660935   0.16743786 -0.09159676  0.0769591 ]
#  [-0.16106887 -0.05787195  0.00540555  0.0162903  -0.04195645  0.09821025
#    0.14109733  0.01520673 -0.07423407 -0.13485222]
#  [ 0.0651696  -0.24212283  0.24196742  0.09809574  0.1038576   0.02700392
#    0.06178211  0.09234786 -0.02734395 -0.02092048]]
#
# [[-0.10668773 -0.2601683  -0.06234038 -0.06414418  0.26529176  0.02480052
#    0.1660935   0.16743786 -0.09159676  0.0769591 ]
#  [-0.16106887 -0.05787195  0.00540555  0.0162903  -0.04195645  0.09821025
#    0.14109733  0.01520673 -0.07423407 -0.13485222]
#  [ 0.0651696  -0.24212283  0.24196742  0.09809574  0.1038576   0.02700392
#    0.06178211  0.09234786 -0.02734395 -0.02092048]]

# %% [markdown]
# ## Eighth exercise

# %%
x = np.loadtxt('03_Assignment_data/03_Assignment_data-D-input.txt')
t = np.loadtxt('03_Assignment_data/03_Assignment_data-D-output.txt')

# force col vec
x.shape = (x.size, 1) 
t.shape = (t.size, 1)

# %%
N = x.shape[0]         # number of samples
ones = np.ones((N,1))

Sig = np.concatenate((ones, x), axis=1)
print Sig
# Out:
# [[ 1.    -1.   ]
#  [ 1.    -0.999]
#  [ 1.    -0.998]
#  ...,
#  [ 1.     0.998]
#  [ 1.     0.999]
#  [ 1.     1.   ]]

# %%
alpha = 2
beta = 25
M = 2

Sni = alpha*np.eye(M) + beta*np.dot(Sig.T,Sig)
Sn = np.linalg.inv(Sni)
mn = beta*np.dot(Sn, np.dot(Sig.T, t))

print mn
print Sig
# Out:
# [[-0.06587564]
#  [ 0.4999401 ]]
# [[ 1.    -1.   ]
#  [ 1.    -0.999]
#  [ 1.    -0.998]
#  ...,
#  [ 1.     0.998]
#  [ 1.     0.999]
#  [ 1.     1.   ]]

# %%
pl.figure()
pl.plot(x,t)
pl.plot(x, np.dot(Sig, mn),'r')
